# %% [markdown]
# # Project X -- Vinay Gannamaneni

# %% [markdown]
# **TA Help:** (for instance) John Smith, Alice Jones, etc., list names of any TAs who helped you
#
# - For example: Help with figuring out how to write a function (describe the tasks that they helped you with)
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Exchange, Stack Overflow, etc.
#
# (describe any information that you learned from internet resources, including the URLs)
# - data frames in Pandas versus R from StackOverflow  https://stackoverflow.com/questions/8991709/why-were-pandas-merges-in-python-faster-than-data-table-merges-in-r-in-2012
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).

# %% [markdown]
# ## Question 1

# %%
myDF <- read.csv("/anvil/projects/tdm/data/movies_and_tv/rotten_tomatoes_movies.csv")
myDF <- myDF[ , !names(myDF) %in% c("cast", "movie_info")]
head(myDF)
# Out:
#   rotten_tomatoes_link
# 1 /m/0814255
# 2 /m/0878835
# 3 /m/10
# 4 /m/1000013-12_angry_men
# 5 /m/1000079-20000_leagues_under_the_sea
# 6 /m/10000_bc
#   movie_title
# 1 Percy Jackson & the Olympians: The Lightning Thief
# 2 Please Give
# 3 10
# 4 12 Angry Men (Twelve Angry Men)
# 5 20,000 Leagues Under The Sea
# 6 10,000 B.C.
#   critics_consensus
# 1 Though it may seem like just another Harry Potter knockoff, Percy Jackson benefits from a strong supporting cast, a speedy plot, and plenty of fun with Greek mythology.
# 2 Nicole Holofcener's newest might seem slight in places, but its rendering of complex characters in a conflicted economic landscape is varied, natural, and touching all the same.
# 3
# 4 Sidney Lumet's feature debut is a superbly written, dramatically effective courtroom thriller that rightfully stands as a modern classic.
# ...

# %% [markdown]
# The table above is the first 6 rows of the data frame without two coloumns: "cast" & "movie_info". As these two columns have a lot of text, the table becomes very messy with these included.

# %%
tail(myDF)
# Out:
#       rotten_tomatoes_link movie_title
# 16633 /m/zoom_2006         Zoom
# 16634 /m/zoot_suit         Zoot Suit
# 16635 /m/zootopia          Zootopia
# 16636 /m/zorba_the_greek   Zorba the Greek
# 16637 /m/zulu              Zulu
# 16638 /m/zulu_dawn         Zulu Dawn
#       critics_consensus
# 16633 Lacking the punch and good cheer of The Incredibles and Sky High, Zoom is a dull and laugh-free affair.
# 16634
# 16635 The brilliantly well-rounded Zootopia offers a thoughtful, inclusive message that's as rich and timely as its sumptuously state-of-the-art animation -- all while remaining fast and funny enough to keep younger viewers entertained.
# 16636
# 16637
# 16638
#       poster_image_url
# 16633 https://resizing.flixster.com/DtmbcT7kLiZBOXFupunpcRuevO8=/206x305/v1.bTsxMTE2OTUzOTtqOzE4MzA5OzEyMDA7NTA5Ozc1NQ
# 16634 https://resizing.flixster.com/aN813Th-ct2RYBoOZsnLEG0ZKGI=/206x305/v1.bTsxMTI5MTE1MTtqOzE4MzEwOzEyMDA7MTUzNjsyMDQ4
# ...

# %% [markdown]
# The above table is the last 6 rows of the data frame (excluding the two columns)

# %%
dim(myDF)
# Out:
# [1] 16638    21

# %% [markdown]
# The above numbers are the dimensions of the table (excluding the two columns)

# %%
table(myDF$rating)
# Out:
#      G   NC17     NR     PG  PG-13 PG-13)      R     R)
#    652     37   4862   2062   2885      3   6136      1

# %% [markdown]
# Now, with the above table of the rating column, we can see how evenly rating levels are distributed across the 16638 rows of movies

# %%
rating_table <- table(myDF$rating)

plot(rating_table, main = "Distribution of Movie Ratings", xlab = "Rating", ylab = "Count of Movies", col = c("navyblue"), lwd = 5)
# Out:
# Plot with title "Distribution of Movie Ratings"

# %% [markdown]
# We can get a better visualization with the plot above. As we can see rating "R" is most prominent in this data frame of movies. My customization is "navyblue" color lines and line weight of "5"

# %% [markdown]
# ## Question 2

# %%
length(table(myDF$rating))
# Out:
# [1] 8

# %%
length(table(myDF$directors))
# Out:
# [1] 8315

# %%
length(table(myDF$studio_name))
# Out:
# [1] 2887

# %% [markdown]
# Since the "directors" and "studio_name" columns have a lot of catagories, we cannot make it into a table. So, we use the "length" command to find out the number of different catagories

# %%
tail(sort(table(myDF$directors[myDF$directors != ""])))
# Out:
# Steven Soderbergh      Sidney Lumet  Steven Spielberg    Clint Eastwood
#                27                30                32                35
#  Alfred Hitchcock       Woody Allen
#                36                36

# %% [markdown]
# To find which person directed the most movies, we can use the "sort" along with "tail" command. Therefore we can see that the director/s with the most movies are 'Alfred Hitchcock' & 'Woody Allen'

# %%
tail(sort(table(myDF$studio_name[myDF$studio_name!=""])))
# Out:
# Sony Pictures Home Entertainment                        IFC Films
#                              379                              398
#                 20th Century Fox               Universal Pictures
#                              414                              469
#            Warner Bros. Pictures               Paramount Pictures
#                              492                              497

# %% [markdown]
# We can also see the studio which produced the most movies which is 'Paramount Pictures'

# %% [markdown]
# ## Question 3

# %%
sum(myDF$genre == "Comedy")
# Out:
# [1] 1202

# %% [markdown]
# Number of movies exclusivly listed as 'Comedy' is 1202

# %%
sum(grepl("Comedy", myDF$genre) & (myDF$genre != "Comedy"))
# Out:
# [1] 4183

# %% [markdown]
# Number of movies which contain multiple genres including 'Comedy' is 4138

# %%
length(grep("Comedy", myDF$genre))
# Out:
# [1] 5385

# %% [markdown]
# Number of all movies that contain 'Comedy' is 5385

# %%
tail(sort(table(myDF$genre[grepl("Comedy", myDF$genre) & (myDF$genre != "Comedy")])))
# Out:
#                    Comedy, Kids & Family
#                                      122
#               Action & Adventure, Comedy
#                                      169
#                          Comedy, Romance
#                                      257
# Art House & International, Comedy, Drama
#                                      260
#                   Comedy, Drama, Romance
#                                      294
#                            Comedy, Drama
#                                      819

# %% [markdown]
# Here we can see that the most common catagory with comedy in it is the combination of 'Comedy & Drama' with a count of 819

# %%
sum(myDF$genre == "Romance")
# Out:
# [1] 14

# %% [markdown]
# Number of movies exclusivly listed as 'Romance' is 14

# %%
sum(grepl("Romance", myDF$genre) & (myDF$genre != "Romance"))
# Out:
# [1] 1793

# %% [markdown]
# Number of movies which contain multiple genres including 'Roamnce' is 1793

# %%
length(grep("Romance", myDF$genre))
# Out:
# [1] 1807

# %% [markdown]
# Number of all movies that contain 'Romance' is 1807

# %% [markdown]
# ## Question 4

# %%
myDF$rating[myDF$rating == "R)"] <- "R"

# %%
myDF$rating[myDF$rating == "PG-13)"] <- "PG-13"

# %% [markdown]
# Here we corrected the typo 'R)' to 'R' & 'PG-13)' to 'PG-13'

# %%
table(myDF$rating, myDF$tomatometer_status)
# Out:
#
#         Certified Fresh Fresh Rotten
#   G                 124   336    192
#   NC17                7    19     11
#   NR                576  3081   1205
#   PG                376   753    933
#   PG-13             563   593   1732
#   R                1311  1666   3160

# %% [markdown]
# Above we have the corrected table of 'tomatometer status'

# %%
mosaicplot(table(myDF$rating, myDF$tomatometer_status), main = "Movie Ratings vs. Tomatometer Status", xlab = "Rating", ylab = "Tomatometer Status", color = c("orange", "darkgreen", "red"))
# Out:
# Plot with title "Movie Ratings vs. Tomatometer Status"

# %% [markdown]
# This is a mosiac plot of 'tomatometer status'

# %% [markdown]
# ## Question 5

# %%
table(paste(myDF$rating, myDF$tomatometer_status))
# Out:
#     G Certified Fresh               G Fresh              G Rotten
#                   124                   336                   192
#  NC17 Certified Fresh            NC17 Fresh           NC17 Rotten
#                     7                    19                    11
#    NR Certified Fresh              NR Fresh             NR Rotten
#                   576                  3081                  1205
#    PG Certified Fresh              PG Fresh             PG Rotten
#                   376                   753                   933
# PG-13 Certified Fresh           PG-13 Fresh          PG-13 Rotten
#                   563                   593                  1732
#     R Certified Fresh               R Fresh              R Rotten
#                  1311                  1666                  3160

# %%
tail(sort(table(paste(myDF$rating, myDF$tomatometer_status))))
# Out:
#         NR Rotten R Certified Fresh           R Fresh      PG-13 Rotten
#              1205              1311              1666              1732
#          NR Fresh          R Rotten
#              3081              3160

# %% [markdown]
# The 'R Rotten' pairing has the most count of 3160

# %%
head(subset(myDF, rating == "PG" & tomatometer_status == "Certified Fresh"))
# Out:
#     rotten_tomatoes_link
# 21  /m/1000355-adventures_of_robin_hood
# 53  /m/1000626-all_about_eve
# 95  /m/10008507-deep_water
# 135 /m/10009001-the_freshman
# 308 /m/1002352-big_sleep
# 340 /m/1003318-butch_cassidy_and_the_sundance_kid
#     movie_title
# 21  The Adventures of Robin Hood
# 53  All About Eve
# 95  Deep Water
# 135 The Freshman
# 308 The Big Sleep
# 340 Butch Cassidy and the Sundance Kid
#     critics_consensus
# 21  Errol Flynn thrills as the legendary title character, and the film embodies the type of imaginative family adventure tailor-made for the silver screen.
# 53  Smart, sophisticated, and devastatingly funny, All About Eve is a Hollywood classic that only improves with age.
# 95  Equal parts mystery and biography, Deep Water is both an engrossing documentary and an affecting treatise on human folly and obsession.
# ...

# %% [markdown]
# The table above shows us the filtered data with the conditions 'rating as PG' and 'tomatometer status as Certifies Fresh'

# %%
subset(myDF, movie_title == "Inception")
subset(myDF, movie_title == "The Dark Knight")
# Out:
#      rotten_tomatoes_link movie_title
# 7865 /m/inception         Inception
#      critics_consensus
# 7865 Smart, innovative, and thrilling, Inception is that rare summer blockbuster that succeeds viscerally as well as intellectually.
#      poster_image_url
# 7865 https://resizing.flixster.com/cZVU45vSaFFv0WGcProRzA5YawI=/206x305/v1.bTsxMTE2NjcyNTtqOzE4MzA5OzEyMDA7ODAwOzEyMDA
#      rating
# 7865 PG-13
#      genre
# 7865 Action & Adventure, Drama, Mystery & Suspense, Science Fiction & Fantasy
#      directors         writers           in_theaters_date on_streaming_date ...
# 7865 Christopher Nolan Christopher Nolan 2010-07-16       2010-12-07        ...
#      studio_name           tomatometer_status tomatometer_rating
# 7865 Warner Bros. Pictures Certified Fresh    87
#      tomatometer_count audience_status audience_rating audience_count
# 7865 351               Upright         91              569611
#      audience_top_critics_count audience_fresh_critics_count
# ...

# %% [markdown]
# I chose to display the details for 'Inception' & 'The Dark Knight' as shown above

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
