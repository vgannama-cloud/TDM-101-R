# %% [markdown]
# # Project X -- Vinay Gannamaneni

# %% [markdown]
# **TA Help:** (for instance) John Smith, Alice Jones, etc., list names of any TAs who helped you
#
# - For example: Help with figuring out how to write a function (describe the tasks that they helped you with)
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Exchange, Stack Overflow, etc.
#
# (describe any information that you learned from internet resources, including the URLs)
# - data frames in Pandas versus R from StackOverflow  https://stackoverflow.com/questions/8991709/why-were-pandas-merges-in-python-faster-than-data-table-merges-in-r-in-2012
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).

# %% [markdown]
# ## Question 1

# %%
%%R
myDF <- read.csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
head(myDF)
# Out:
#   iata airport              city             state country lat      long
# 1 00M  Thigpen              Bay Springs      MS    USA     31.95376  -89.23450
# 2 00R  Livingston Municipal Livingston       TX    USA     30.68586  -95.01793
# 3 00V  Meadow Lake          Colorado Springs CO    USA     38.94575 -104.56989
# 4 01G  Perry-Warsaw         Perry            NY    USA     42.74135  -78.05208
# 5 01J  Hilliard Airpark     Hilliard         FL    USA     30.68801  -81.90594
# 6 01M  Tishomingo County    Belmont          MS    USA     34.49167  -88.20111

# %%
%%R
head(myDF, n=12)
# Out:
#    iata airport              city             state country lat      long
# 1  00M  Thigpen              Bay Springs      MS    USA     31.95376  -89.23450
# 2  00R  Livingston Municipal Livingston       TX    USA     30.68586  -95.01793
# 3  00V  Meadow Lake          Colorado Springs CO    USA     38.94575 -104.56989
# 4  01G  Perry-Warsaw         Perry            NY    USA     42.74135  -78.05208
# 5  01J  Hilliard Airpark     Hilliard         FL    USA     30.68801  -81.90594
# 6  01M  Tishomingo County    Belmont          MS    USA     34.49167  -88.20111
# 7  02A  Gragg-Wade           Clanton          AL    USA     32.85049  -86.61145
# 8  02C  Capitol              Brookfield       WI    USA     43.08751  -88.17787
# 9  02G  Columbiana County    East Liverpool   OH    USA     40.67331  -80.64141
# 10 03D  Memphis Memorial     Memphis          MO    USA     40.44726  -92.22696
# 11 04M  Calhoun County       Pittsboro        MS    USA     33.93011  -89.34285
# 12 04Y  Hawley Municipal     Hawley           MN    USA     46.88385  -96.35090

# %% [markdown]
# Firstly, I used "%%R" because I am using "seminar" kernel. I named the given data as 'myDF' and used the "head" command to display the first 6 rows of the given data.
#
# In the second cell, I defined the "head" to be 12 rows instead of 6 so it displayed the first 12 rows of the data.

# %% [markdown]
# ## Question 2

# %%
myDF <- read.csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
head(myDF, n=12)
# Out:
#    iata airport              city             state country lat      long
# 1  00M  Thigpen              Bay Springs      MS    USA     31.95376  -89.23450
# 2  00R  Livingston Municipal Livingston       TX    USA     30.68586  -95.01793
# 3  00V  Meadow Lake          Colorado Springs CO    USA     38.94575 -104.56989
# 4  01G  Perry-Warsaw         Perry            NY    USA     42.74135  -78.05208
# 5  01J  Hilliard Airpark     Hilliard         FL    USA     30.68801  -81.90594
# 6  01M  Tishomingo County    Belmont          MS    USA     34.49167  -88.20111
# 7  02A  Gragg-Wade           Clanton          AL    USA     32.85049  -86.61145
# 8  02C  Capitol              Brookfield       WI    USA     43.08751  -88.17787
# 9  02G  Columbiana County    East Liverpool   OH    USA     40.67331  -80.64141
# 10 03D  Memphis Memorial     Memphis          MO    USA     40.44726  -92.22696
# 11 04M  Calhoun County       Pittsboro        MS    USA     33.93011  -89.34285
# 12 04Y  Hawley Municipal     Hawley           MN    USA     46.88385  -96.35090

# %%
myIndyDF <- subset(myDF, state=="IN")
head(myIndyDF, n=10)
# Out:
#     iata airport                  city        state country lat      long
# 13  05C  Griffith-Merrillville    Griffith    IN    USA     41.51962 -87.40109
# 22  07C  Dekalb County            Auburn      IN    USA     41.30717 -85.06433
# 163 1I9  Delphi Municipal         Delphi      IN    USA     40.54281 -86.68167
# 437 4I7  Putnam County            Greencastle IN    USA     39.63360 -86.81383
# 478 50I  Kentland Municipal       Kentland    IN    USA     40.75873 -87.42822
# 515 5I4  Sheridan                 Sheridan    IN    USA     40.17793 -86.21730
# 803 AID  Anderson Municipal       Anderson    IN    USA     40.10862 -85.61299
# 844 ANQ  Steuben County-Tri State Angola      IN    USA     41.63970 -85.08349
# 877 ASW  Warsaw Municipal         Warsaw      IN    USA     41.27470 -85.84006
# 919 BAK  Columbus Municipal       Columbus    IN    USA     39.26192 -85.89635

# %%
dim(myIndyDF) #We have 65 rows and 7 columns in this data frame
# Out:
# [1] 65  7

# %% [markdown]
# Now I switch to "seminar-r" kernel so I dont have to type in the "%%R" in the beginning.
# To find airports located in Indiana, I first make a data subset of the original data frame and equate state to "IN"
# By again using the "head" command defining it to "n=10", I can see the first 10 airports located in Indiana.
# With the "dim" command, I can see the total number of airports in a data frame. So, in Indiana there are 65 airports in total.

# %% [markdown]
# ## Question 3

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/flights/subset/2007.csv")

# %%
table(myDF$Origin)
# Out:
#    ABE    ABI    ABQ    ABY    ACK    ACT    ACV    ACY    ADK    ADQ    AEX
#   5701   2836  41161   1312    314   2349   3872    735    103    691   2996
#    AGS    AKN    ALB    ALO    AMA    ANC    APF    ASE    ATL    ATW    AUS
#   2286    235  14965    300   7542  19755    555   5305 413851   6179  51560
#    AVL    AVP    AZO    BDL    BET    BFL    BGM    BGR    BHM    BIL    BIS
#   3773   2890   5121  32627   1044   5195    966   4091  23535   4694   3155
#    BJI    BLI    BMI    BNA    BOI    BOS    BPT    BQK    BQN    BRO    BRW
#    128    588   4219  61070  18106 128320    364    993   1370   1593    726
#    BTM    BTR    BTV    BUF    BUR    BWI    BZN    CAE    CAK    CDV    CEC
#    819  10347   7239  26687  33019 109385   5237  10660   9335    726   1055
#    CHA    CHO    CHS    CIC    CID    CLD    CLE    CLL    CLT    CMH    CMI
#   4533   1386  15673   1374  11151   2730  78288   1785 127108  38544   2757
#    CMX    COD    COS    CPR    CRP    CRW    CSG    CVG    CWA    DAB    DAL
#    309   1336  17233   3890   6769   3498   1398 110509   1773   3687  53951
#    DAY    DBQ    DCA    DEN    DFW    DHN    DLG    DLH    DRO    DSM    DTW
#  15810   1415  89666 240928 297345   1639    175   2188   3939  17872 177478
#    EAU    EGE    EKO    ELM    ELP    ERI    EUG    EVV    EWN    EWR    EYW
#     72   3355   1819   1205  21805   1358   6369   5832    601 154113   1052
#    FAI    FAR    FAT    FAY    FCA    FLG    FLL    FLO    FNT    FSD    FSM
#   4968   5300  15709   2185   3305   1911  69414    655   7775   6781   2735
#    FWA    GEG    GFK    GGG    GJT    GLH    GNV    GPT    GRB    GRK    GRR
#   6593  16135   1220   1093   4858      2   1927   7330   8434   5149  16412
#    GSO    GSP    GST    GTF    GTR    GUC    HDN    HHH    HLN    HNL    HOU
#  14980  13507     90   2917   1006   1273   2685    997   1803  67581  56540
#    HPN    HRL    HSV    HTS    IAD    IAH    ICT    IDA    ILG    ILM    IND
#  12569   5055   9792    279  91048 200420  14750   3383    455   3815  43576
#    INL    IPL    ISO    ISP    ITO    IYK    JAC    JAN    JAX    JFK    JNU
#    218   1300      9  12222   9570    981   3517  13589  35931 126366   4447
#    KOA    KTN    LAN    LAS    LAW    LAX    LBB    LCH    LEX    LFT    LGA
#  16001   2388   4602 183668   2333 237597   8704   1204   9980   5713 122899
#    LGB    LIH    LIT    LNK    LRD    LSE    LWB    LWS    LYH    MAF    MBS
#  14210  15677  17009   4218   2543   2512    187    706    877   7604   3744
#    MCI    MCN    MCO    MDT    MDW    MEI    MEM    MFE    MFR    MGM    MHT
#  65011    992 129778   8795  95863    678  85034   4733   6389   4085  21349
#    MIA    MKC    MKE    MLB    MLI    MLU    MOB    MOD    MOT    MQT    MRY
#  64742      1  28404   2044   9516   3094   6171   3060   1080   1069   8768
#    MSN    MSO    MSP    MSY    MTH    MTJ    MYR    OAJ    OAK    OGG    OKC
#  13416   3807 155846  37329    128   2606   6764   1134  74938  25515  26964
#    OMA    OME    ONT    ORD    ORF    OTZ    OXR    PBI    PDX    PFN    PHF
#  28081   1088  41643 375784  20012   1086   1358  29766  58603   3468   5548
#    PHL    PHX    PIA    PIH    PIR    PIT    PLN    PMD    PNS    PSC    PSE
# 104063 211072   5417   1824      4  49209    512    392  10280   2736   1001
#    PSG    PSP    PVD    PWM    RAP    RDD    RDM    RDU    RFD    RHI    RIC
#    726  13201  25366   8368   5023   1793   3646  67199    694    223  19857
#    RNO    ROA    ROC    ROW    RST    RSW    SAN    SAT    SAV    SBA    SBN
#  27211   3707  17274    235   4252  27615  97316  46362  14281  14274   5128
#    SBP    SCC    SCE    SDF    SEA    SFO    SGF    SGU    SHV    SIT    SJC
#   7052    726    677  22229 109127 138491  11058   3636   8969   1340  61804
#    SJT    SJU    SLC    SLE    SMF    SMX    SNA    SOP    SPI    SPS    SRQ
#   1822  23709 147808    398  58074   1761  52953    195   1745   2316   7331
#    STL    STT    STX    SUN    SUX    SWF    SYR    TEX    TLH    TOL    TPA
#  64856   2955    479   3208    534   5592  13265    216   4231   2096  79785
#    TRI    TTN    TUL    TUP    TUS    TVC    TWF    TXK    TYR    TYS    VLD
#   1207    808  25175    603  28173   4137   2099   1208   1604  13965   1057
#    VPS    WRG    WYS    XNA    YAK    YKM    YUM
#   6927    726    266  14025    726    410   3524

# %%
sort(table(myDF$Origin))
# Out:
#    MKC    GLH    PIR    ISO    EAU    GST    ADK    BJI    MTH    DLG    LWB
#      1      2      4      9     72     90    103    128    128    175    187
#    SOP    TEX    INL    RHI    AKN    ROW    WYS    HTS    ALO    CMX    ACK
#    195    216    218    223    235    235    266    279    300    309    314
#    BPT    PMD    SLE    YKM    ILG    STX    PLN    SUX    APF    BLI    EWN
#    364    392    398    410    455    479    512    534    555    588    601
#    TUP    FLO    SCE    MEI    ADQ    RFD    LWS    BRW    CDV    PSG    SCC
#    603    655    677    678    691    694    706    726    726    726    726
#    WRG    YAK    ACY    TTN    BTM    LYH    BGM    IYK    MCN    BQK    HHH
#    726    726    735    808    819    877    966    981    992    993    997
#    PSE    GTR    BET    EYW    CEC    VLD    MQT    MOT    OTZ    OME    GGG
#   1001   1006   1044   1052   1055   1057   1069   1080   1086   1088   1093
#    OAJ    LCH    ELM    TRI    TXK    GFK    GUC    IPL    ABY    COD    SIT
#   1134   1204   1205   1207   1208   1220   1273   1300   1312   1336   1340
#    ERI    OXR    BQN    CIC    CHO    CSG    DBQ    BRO    TYR    DHN    SPI
#   1358   1358   1370   1374   1386   1398   1415   1593   1604   1639   1745
#    SMX    CWA    CLL    RDD    HLN    EKO    SJT    PIH    FLG    GNV    MLB
#   1761   1773   1785   1793   1803   1819   1822   1824   1911   1927   2044
#    TOL    TWF    FAY    DLH    AGS    SPS    LAW    ACT    KTN    LSE    LRD
#   2096   2099   2185   2188   2286   2316   2333   2349   2388   2512   2543
#    MTJ    HDN    CLD    FSM    PSC    CMI    ABI    AVP    GTF    STT    AEX
#   2606   2685   2730   2735   2736   2757   2836   2890   2917   2955   2996
#    MOD    MLU    BIS    SUN    FCA    EGE    IDA    PFN    CRW    JAC    YUM
#   3060   3094   3155   3208   3305   3355   3383   3468   3498   3517   3524
#    SGU    RDM    DAB    ROA    MBS    AVL    MSO    ILM    ACV    CPR    DRO
#   3636   3646   3687   3707   3744   3773   3807   3815   3872   3890   3939
#    MGM    BGR    TVC    LNK    BMI    TLH    RST    JNU    CHA    LAN    BIL
#   4085   4091   4137   4218   4219   4231   4252   4447   4533   4602   4694
#    MFE    GJT    FAI    RAP    HRL    AZO    SBN    GRK    BFL    BZN    FAR
#   4733   4858   4968   5023   5055   5121   5128   5149   5195   5237   5300
#    ASE    PIA    PHF    SWF    ABE    LFT    EVV    MOB    ATW    EUG    MFR
#   5305   5417   5548   5592   5701   5713   5832   6171   6179   6369   6389
#    FWA    MYR    CRP    FSD    VPS    SBP    BTV    GPT    SRQ    AMA    MAF
#   6593   6764   6769   6781   6927   7052   7239   7330   7331   7542   7604
#    FNT    PWM    GRB    LBB    MRY    MDT    SHV    CAK    MLI    ITO    HSV
#   7775   8368   8434   8704   8768   8795   8969   9335   9516   9570   9792
#    LEX    PNS    BTR    CAE    SGF    CID    ISP    HPN    PSP    SYR    MSN
#   9980  10280  10347  10660  11058  11151  12222  12569  13201  13265  13416
#    GSP    JAN    TYS    XNA    LGB    SBA    SAV    ICT    ALB    GSO    CHS
#  13507  13589  13965  14025  14210  14274  14281  14750  14965  14980  15673
#    LIH    FAT    DAY    KOA    GEG    GRR    LIT    COS    ROC    DSM    BOI
#  15677  15709  15810  16001  16135  16412  17009  17233  17274  17872  18106
#    ANC    RIC    ORF    MHT    ELP    SDF    BHM    SJU    TUL    PVD    OGG
#  19755  19857  20012  21349  21805  22229  23535  23709  25175  25366  25515
#    BUF    OKC    RNO    RSW    OMA    TUS    MKE    PBI    BDL    BUR    JAX
#  26687  26964  27211  27615  28081  28173  28404  29766  32627  33019  35931
#    MSY    CMH    ABQ    ONT    IND    SAT    PIT    AUS    SNA    DAL    HOU
#  37329  38544  41161  41643  43576  46362  49209  51560  52953  53951  56540
#    SMF    PDX    BNA    SJC    MIA    STL    MCI    RDU    HNL    FLL    OAK
#  58074  58603  61070  61804  64742  64856  65011  67199  67581  69414  74938
#    CLE    TPA    MEM    DCA    IAD    MDW    SAN    PHL    SEA    BWI    CVG
#  78288  79785  85034  89666  91048  95863  97316 104063 109127 109385 110509
#    LGA    JFK    CLT    BOS    MCO    SFO    SLC    EWR    MSP    DTW    LAS
# 122899 126366 127108 128320 129778 138491 147808 154113 155846 177478 183668
#    IAH    PHX    LAX    DEN    DFW    ORD    ATL
# 200420 211072 237597 240928 297345 375784 413851

# %%
tail(sort(table(myDF$Origin)), n=20)
# Out:
#    BWI    CVG    LGA    JFK    CLT    BOS    MCO    SFO    SLC    EWR    MSP
# 109385 110509 122899 126366 127108 128320 129778 138491 147808 154113 155846
#    DTW    LAS    IAH    PHX    LAX    DEN    DFW    ORD    ATL
# 177478 183668 200420 211072 237597 240928 297345 375784 413851

# %% [markdown]
# We use another library called "data.table" as the data is very large. Then we import the required data frame.
# Next we use the "table" command for the "Origin" column to organize the given data into a table which will tell us the number of flights that originate from each airport.
# With the "sort" command, we can get this data in ascending order.
# Similar to the "head" command, we can use "tail, n=20" which gives us the bottom rows of the data frame.
# And, finally we have the top 20 most popular airports.

# %% [markdown]
# ## Question 4

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv")
table(myDF$City)
# Out:
#            Albertville              Amsterdam              Antwerpen
#                   3436                   4992                   4292
#                 Athina                Atlanta              Barcelona
#                  15556                  13780                  12977
#                Beijing                 Berlin                Calgary
#                  13602                   6506                   2639
#               Chamonix      Cortina d'Ampezzo Garmisch-Partenkirchen
#                    460                   1307                    895
#               Grenoble               Helsinki              Innsbruck
#                   1891                   8270                   3639
#            Lake Placid            Lillehammer                 London
#                   2098                   3160                  22426
#            Los Angeles              Melbourne            Mexico City
#                  12423                   4829                   8588
#               Montreal                 Moskva                 Munich
#                   8641                   7191                  10304
#                 Nagano                   Oslo                  Paris
#                   3605                   1088                   7169
#         Rio de Janeiro                   Roma         Salt Lake City
#                  13688                   8119                   4109
#           Sankt Moritz                Sapporo               Sarajevo
#                   1657                   1655                   2134
#                  Seoul                  Sochi           Squaw Valley
#                  12037                   4891                   1116
#              St. Louis              Stockholm                 Sydney
#                   1301                   4338                  13821
#                  Tokyo                 Torino              Vancouver
#                   7702                   4382                   4402

# %%
sort(table(myDF$City))
# Out:
#               Chamonix Garmisch-Partenkirchen                   Oslo
#                    460                    895                   1088
#           Squaw Valley              St. Louis      Cortina d'Ampezzo
#                   1116                   1301                   1307
#                Sapporo           Sankt Moritz               Grenoble
#                   1655                   1657                   1891
#            Lake Placid               Sarajevo                Calgary
#                   2098                   2134                   2639
#            Lillehammer            Albertville                 Nagano
#                   3160                   3436                   3605
#              Innsbruck         Salt Lake City              Antwerpen
#                   3639                   4109                   4292
#              Stockholm                 Torino              Vancouver
#                   4338                   4382                   4402
#              Melbourne                  Sochi              Amsterdam
#                   4829                   4891                   4992
#                 Berlin                  Paris                 Moskva
#                   6506                   7169                   7191
#                  Tokyo                   Roma               Helsinki
#                   7702                   8119                   8270
#            Mexico City               Montreal                 Munich
#                   8588                   8641                  10304
#                  Seoul            Los Angeles              Barcelona
#                  12037                  12423                  12977
#                Beijing         Rio de Janeiro                Atlanta
#                  13602                  13688                  13780
#                 Sydney                 Athina                 London
#                  13821                  15556                  22426

# %%
tail(sort(table(myDF$City)), n=10)
# Out:
#         Munich          Seoul    Los Angeles      Barcelona        Beijing
#          10304          12037          12423          12977          13602
# Rio de Janeiro        Atlanta         Sydney         Athina         London
#          13688          13780          13821          15556          22426

# %% [markdown]
# We use the same commands used in "Question 3" to arrange the data frame in a table.
# Then we again use "sort" and "tail" commands to get our required data.

# %% [markdown]
# ## Question 5

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/flights/subset/2007.csv")
dotchart(tail(sort(table(myDF$Origin)), n=20))
# Out:
# Warning message in dotchart(tail(sort(table(myDF$Origin)), n = 20)):
# "'x' is neither a vector nor a matrix: using as.numeric(x)"
# plot without title

# %%
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv")
dotchart(tail(sort(table(myDF$City)), n=10))
# Out:
# Warning message in dotchart(tail(sort(table(myDF$City)), n = 10)):
# "'x' is neither a vector nor a matrix: using as.numeric(x)"
# plot without title

# %% [markdown]
# Now finally to get dotcharts for both data fram, import each DF seperately and use the "dotchart" command.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
