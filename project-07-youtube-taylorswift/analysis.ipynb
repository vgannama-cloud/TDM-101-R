# %% [markdown]
# # Project 7 -- Vinay Gannamaneni

# %% [markdown]
# **TA Help:** (for instance) John Smith, Alice Jones, etc., list names of any TAs who helped you
#
# - For example: Help with figuring out how to write a function (describe the tasks that they helped you with)
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Exchange, Stack Overflow, etc.
#
# (describe any information that you learned from internet resources, including the URLs)
# - data frames in Pandas versus R from StackOverflow  https://stackoverflow.com/questions/8991709/why-were-pandas-merges-in-python-faster-than-data-table-merges-in-r-in-2012
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# - ***Link to AI Chat History***: Please share a link to your chat if you used AI (ex. ChatGPT Shared Links)
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).

# %% [markdown]
# ## Cleaning video counts and aggregating by YouTube category

# %%
youtubers <- read.csv("/anvil/projects/tdm/data/youtube/most_subscribed_youtube_channels.csv")
youtubers$video.count2 <- as.numeric(gsub(",", "", youtubers$video.count))

# %% [markdown]
# Read the data set and clean the "video.count" column and create a numeric version

# %%
category_counts <- tapply(youtubers$video.count2, youtubers$category, sum, na.rm = TRUE)
print(category_counts)
# Out:
#                            Autos & Vehicles                Comedy
#                 11230                  2874                 93562
#             Education         Entertainment      Film & Animation
#                124727               2674176                133319
#                Gaming         Howto & Style                Movies
#                427292                 81419                  5576
#                 Music       News & Politics Nonprofits & Activism
#                510337               2754693                188445
#        People & Blogs        Pets & Animals  Science & Technology
#               1045091                 23960                 36622
#                 Shows                Sports              Trailers
#                283027                140464                 13613
#       Travel & Events
#                   632

# %% [markdown]
# Total videos per catagory

# %%
barplot(category_counts,
        las = 2,
        col = "red",
        main = "Total Videos by YouTube Category",
        xlab = "Category",
        ylab = "Total Videos")
# Out:
# Plot with title "Total Videos by YouTube Category"

# %% [markdown]
# "News & Politics" had most total videos overall

# %%
gm <- subset(youtubers, category %in% c("Gaming", "Music"))
gm_counts <- tapply(gm$video.count2, list(gm$category, gm$started), sum, na.rm = TRUE)
gm_counts
# Out:
#        2005  2006   2007  2008  2009  2010  2011  2012  2013  2014   2015 2016
# Gaming 17878 163116 11967 16356 15342  9998 27421 72858 32267  31332 7342 7903
# Music   1446  36423 51621 33451 16392 31766 89353 44299 71681 119692 5447 8477
#        2017 2018 2019 2020
# Gaming 9302 2952 1126 132
# Music   156  121   12  NA

# %% [markdown]
# Total videos by each catagory by started year

# %%
barplot(gm_counts,
        beside = TRUE,
        col = c("tomato", "steelblue"),
        main = "Total Videos by Category and Start Year",
        xlab = "Start Year",
        ylab = "Total Videos")
legend("topright", legend = rownames(gm_counts), fill = c("tomato", "steelblue"))
# Out:
# Plot with title "Total Videos by Category and Start Year"

# %% [markdown]
# Gaming channels started in 2006 produced the most videos overall

# %%
avg_videos_year <- tapply(youtubers$video.count2, youtubers$started, mean, na.rm = TRUE)
print(avg_videos_year)
# Out:
#      1970      2005      2006      2007      2008      2009      2010      2011
#   540.000 15480.409 16612.625 24476.800 14807.333 10564.381  9957.319  5772.118
#      2012      2013      2014      2015      2016      2017      2018      2019
#  7142.812  7368.140  8370.807  4237.699  2594.442  5168.783  6515.543  2673.560
#      2020      2021
#  1385.000   696.750

# %% [markdown]
# Average video count for each start year

# %%
plot(names(avg_videos_year), avg_videos_year,
     type = "b",
     pch = 19,
     col = "purple",
     main = "Average Video Count by Start Year",
     xlab = "Start Year",
     ylab = "Average Video Count")
# Out:
# Plot with title "Average Video Count by Start Year"

# %% [markdown]
# Around 14,807 videos per channel in 2008

# %% [markdown]
# ## Custom functions to filter songs by energy level and by album

# %%
ts_songs <- read.csv2("/anvil/projects/tdm/data/spotify/taylor_swift_discography_updated.csv")
dim(ts_songs)
# Out:
# [1] 577  28

# %%
ts_songs <- ts_songs[ , !(names(ts_songs) %in% "track_lyrics")]
head(ts_songs)
# Out:
#   X...ID track_name                           track_musical_genre track_type
# 1 0      Fortnight (feat. Post Malone)        Synth Pop           Single
# 2 1      The Tortured Poets Department        Synth Pop           B-Side
# 3 2      My Boy Only Breaks His Favorite Toys Synth Pop           B-Side
# 4 3      Down Bad                             R&B                 B-Side
# 5 4      So Long, London                      Synth Pop           B-Side
# 6 5      But Daddy I Love Him                 Pop Rock            B-Side
#   duration_ms feature     track_videoclip videoclip_views spotify_streams
# 1 228965      Post Malone No              0               648525069
# 2 293048      No          No              0               206954130
# 3 203801      No          No              0               238016975
# 4 261228      No          No              0               318375377
# 5 262974      No          No              0               253712712
# 6 340428      No          No              0               229410536
#   spotify_global_peak album                                        track_number
# 1 1                   The Tortured Poets Department: The Anthology 1
# 2 6                   The Tortured Poets Department: The Anthology 2
# 3 7                   The Tortured Poets Department: The Anthology 3
# 4 2                   The Tortured Poets Department: The Anthology 4
# 5 4                   The Tortured Poets Department: The Anthology 5
# 6 9                   The Tortured Poets Department: The Anthology 6
#   album_musical_genre album_type         release_date album_physical_sales
# 1 Pop                 Compilation/Deluxe 19/4/2024    0
# 2 Pop                 Compilation/Deluxe 19/4/2024    0
# 3 Pop                 Compilation/Deluxe 19/4/2024    0
# 4 Pop                 Compilation/Deluxe 19/4/2024    0
# 5 Pop                 Compilation/Deluxe 19/4/2024    0
# 6 Pop                 Compilation/Deluxe 19/4/2024    0
#   track_theme                       uri
# 1 Complicated love/Looking for love spotify:track:6dODwocEuGzHAavXqTbwHv
# 2 Complicated love/Looking for love spotify:track:4PdLaGZubp4lghChqp8erB
# 3 Broken heart/Sadness              spotify:track:7uGYWMwRy24dm7RUDDhUlD
# 4 Broken heart/Sadness              spotify:track:1kbEbBdEgQdQeLXCJh28pJ
# 5 Broken heart/Sadness              spotify:track:7wAkQFShJ27V8362MqevQr
# 6 Complicated love/Looking for love spotify:track:4QMgEffJQuKtjCNvqfRZ0m
#   acousticness danceability energy instrumentalness liveness loudness
# 1 0.502        0.504        0.386  1.53e-05         0.0961   -10.976
# 2 0.0483       0.604        0.428  0.0              0.126    -8.441
# 3 0.137        0.596        0.563  0.0              0.302    -7.362
# 4 0.56         0.541        0.366  1,00E-06         0.0946   -10.412
# 5 0.73         0.423        0.533  0.00264          0.0816   -11.388
# 6 0.384        0.521        0.72   0.0              0.135    -7.684
#   speechiness tempo   valence numeric_streams cleaned_streams
# 1 0.0308      192.004 0.281   648525069       648525069
# 2 0.0255      110.259 0.292   206954130       206954130
# 3 0.0269      97.073  0.481   238016975       238016975
# 4 0.0748      159.707 0.168   318375377       318375377
# 5 0.322       160.218 0.248   253712712       253712712
# 6 0.104       79.943  0.438   229410536       229410536

# %% [markdown]
# Removed the "lyrics" column

# %%
ts_songs$energy <- as.numeric(ts_songs$energy)
summary(ts_songs$energy)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.1180  0.4170  0.5700  0.5649  0.7200  0.9500

# %% [markdown]
# Check "energy" numeric forms to get statistics on median, min, and max

# %% [markdown]
# The maximum energy level possible is 0.950. The minimum energy level possible is 0.008

# %%
find_songs_with_energy <- function(input_df, threshold) {
  my_output <- input_df[input_df$energy >= threshold, ]
  return(my_output)
}

medianset <- median(ts_songs$energy, na.rm = TRUE)

# %% [markdown]
# Use function to get all high energy songs

# %%
high_energy_df <- find_songs_with_energy(ts_songs, medianset)
nrow(high_energy_df)
# Out:
# [1] 289

# %% [markdown]
# 289 songs had high energy in total

# %%
find_songs_by_album <- function(input_df, album_name) {
  input_df$album <- trimws(input_df$album)
  album_songs <- input_df[tolower(input_df$album) == tolower(album_name), ]
  
  return(album_songs)
}

# %% [markdown]
# Build function to find songs by album

# %%
tortured_poets <- find_songs_by_album(ts_songs, "The Tortured Poets Department: The Anthology")
nrow(tortured_poets)
# Out:
# [1] 31

# %% [markdown]
# The funtion works cus "The Tortured Poets Department: The Anthology" contains 31 songs

# %% [markdown]
# ## Cleaning malformed streaming numbers

# %%
ts_songs$numeric_streams <- as.numeric(ts_songs$spotify_streams)
problematic_values <- ts_songs[is.na(ts_songs$numeric_streams) & !is.na(ts_songs$spotify_streams), "spotify_streams"]
problematic_values
# Out:
# Warning message:
# "NAs introduced by coercion"
#   [1] "102.221.045"   "151.282.408"   "182.418.311"   "118.458.965"
#   [5] "88.205.974"    "101.800.187"   "77.667.730"    "75.816.684"
#   [9] "695.045.271"   "64.895.368"    "238.858.492"   "66.435.115"
#  [13] "86.966.267"    "65.608.381"    "67.947.237"    "106.436.747"
#  [17] "239.579.759"   "161.739.029"   "243.929.951"   "97.666.137"
#  [21] "327.037.965"   "57.248.658"    "102.221.045"   "151.282.408"
#  [25] "182.418.311"   "118.458.965"   "88.205.974"    "101.800.187"
#  [29] "77.667.730"    "75.816.684"    "695.045.271"   "64.895.368"
#  [33] "238.858.492"   "66.435.115"    "86.966.267"    "65.608.381"
#  [37] "67.947.237"    "106.436.747"   "239.579.759"   "161.739.029"
#  [41] "243.929.951"   "97.666.137"    "327.037.965"   "161.201.338"
#  [45] "111.149.636"   "180.262.965"   "95.341.130"    "99.582.468"
#  [49] "91.554.198"    "89.206.080"    "52.613.223"    "256.720.162"
#  [53] "116.688.485"   "44.117.403"    "72.179.901"    "72.138.383"
#  [57] "119.043.402"   "50.628.387"    "37.442.081"    "79.599.951"
#  [61] "75.501.290"    "233.537.019"   "77.280.948"    "85.579.355"
#  [65] "78.097.730"    "685.569.376"   "442.240.497"   "1.497.861.842"
#  [69] "418.499.855"   "558.461.539"   "631.931.332"   "289.677.180"
#  [73] "379.998.152"   "511.571.475"   "263.703.912"   "737.680.743"
#  [77] "265.543.423"   "328.656.338"   "269.420.309"   "175.821.082"
#  [81] "176.277.983"   "148.303.282"   "118.355.491"   "257.804.372"
#  [85] "123.378.107"   "177.054.741"   "172.680.008"   "86.528.064"
#  [89] "685.569.376"   "442.240.497"   "1.497.861.842" "418.499.855"
#  [93] "558.461.539"   "631.931.332"   "289.677.180"   "379.998.152"
#  [97] "511.571.475"   "263.703.912"   "737.680.743"   "265.543.423"
# [101] "328.656.338"   "269.420.309"   "175.821.082"   "176.277.983"
# [105] "148.303.282"   "118.355.491"   "257.804.372"   "123.378.107"
# [109] "685.569.376"   "442.240.497"   "1.497.861.842" "418.499.855"
# [113] "558.461.539"   "631.931.332"   "289.677.180"   "379.998.152"
# [117] "511.571.475"   "263.703.912"   "737.680.743"   "265.543.423"
# [121] "328.656.338"   "119.887.717"   "276.457.730"   "107.168.641"
# [125] "331.115.790"   "249.885.271"   "265.698.765"   "89.369.701"
# [129] "315.588.138"   "86.371.415"    "108.741.392"   "84.058.644"
# [133] "93.349.578"    "74.802.137"    "144.156.621"   "68.667.868"
# [137] "98.591.643"    "69.027.319"    "108.053.400"   "56.901.647"
# [141] "51.126.307"    "42.569.086"    "139.140.884"   "209.924.444"
# [145] "118.151.653"   "185.024.136"   "206.457.482"   "90.351.777"
# [149] "135.457.781"   "166.946.516"   "810.542.565"   "276.701.835"
# [153] "97.490.294"    "714.184.368"   "86.368.640"    "94.810.816"
# [157] "619.978.693"   "64.707.634"    "55.729.532"    "70.295.638"
# [161] "397.666.679"   "107.430.716"   "50.543.835"    "43.303.976"
# [165] "54.359.548"    "55.397.353"    "50.407.943"    "39.608.696"
# [169] "35.505.550"    "69.531.567"    "51.835.918"    "109.187.805"
# [173] "358.733.130"   "57.957.104"    "76.512.224"    "68.743.624"
# [177] "53.973.432"    "814.114.651"   "588.394.719"   "279.044.935"
# [181] "260.055.245"   "297.807.837"   "266.696.518"   "180.744.525"
# [185] "168.010.057"   "174.430.479"   "211.246.717"   "180.507.774"
# [189] "190.498.817"   "205.207.043"   "119.250.347"   "208.212.731"
# [193] "315.084.417"   "105.356.578"   "814.114.651"   "588.394.719"
# [197] "279.044.935"   "260.055.245"   "297.807.837"   "266.696.518"
# [201] "180.744.525"   "168.010.057"   "174.430.479"   "211.246.717"
# [205] "180.507.774"   "190.498.817"   "205.207.043"   "119.250.347"
# [209] "208.212.731"   "552.789.777"   "1.240.468.789" "350.113.872"
# [213] "732.129.402"   "456.830.802"   "401.624.104"   "298.361.936"
# [217] "1.039.423.219" "375.813.987"   "389.023.820"   "351.443.321"
# [221] "206.915.468"   "179.012.062"   "339.198.629"   "202.357.820"
# [225] "180.324.854"   "147.911.887"   "17.256.353"    "22.319.608"
# [229] "13.105.439"    "44.782.909"    "21.032.667"    "16.067.602"
# [233] "12.738.080"    "20.062.707"    "18.997.642"    "14.930.318"
# [237] "12.187.198"    "10.113.780"    "9.431.619"     "12.112.084"
# [241] "10.237.759"    "11.466.753"    "14.461.249"    "552.789.777"
# [245] "1.240.468.789" "350.113.872"   "732.129.402"   "456.830.802"
# [249] "401.624.104"   "298.361.936"   "1.039.423.219" "375.813.987"
# [253] "389.023.820"   "351.443.321"   "206.915.468"   "179.012.062"
# [257] "339.198.629"   "202.357.820"   "180.324.854"   "147.911.887"
# [261] "552.789.777"   "1.240.468.789" "350.113.872"   "732.129.402"
# [265] "456.830.802"   "401.624.104"   "298.361.936"   "1.039.423.219"
# [269] "375.813.987"   "389.023.820"   "351.443.321"   "206.915.468"
# [273] "179.012.062"   "339.198.629"   "202.357.820"   "180.324.854"
# [277] "329.817.595"   "1.993.770.030" "1.337.934.671" "728.980.010"
# [281] "382.363.955"   "266.772.382"   "356.974.249"   "624.943.370"
# [285] "318.912.167"   "279.089.879"   "318.393.019"   "140.953.878"
# [289] "226.705.140"   "905.599.541"   "368.409.481"   "844.254.273"
# [293] "128.678.253"   "379.786.759"   "695.895.392"   "485.674.511"
# [297] "427.923.904"   "1.066.236.494" "957.363.618"   "1.119.518.781"
# [301] "176.212.321"   "579.204.888"   "640.936.966"   "260.615.846"
# [305] "243.124.768"   "313.580.941"   "215.037.292"   "389.833.661"
# [309] "189.251.406"   "245.010.202"   "941.509.249"   "39.494.267"
# [313] "251.775.054"   "54.079.110"    "210.533.930"   "328.676.348"
# [317] "383.038.883"   "815.642.450"   "1.625.559.303" "227.152.677"
# [321] "168.171.382"   "176.212.321"   "114.830.649"   "220.866.384"
# [325] "180.160.266"   "60.819.145"    "102.177.470"   "84.836.384"
# [329] "54.965.296"    "111.448.042"   "245.267.622"   "118.010.086"
# [333] "786.707.238"   "26.816.334"    "71.272.101"    "321.275.673"
# [337] "42.188.665"    "40.680.546"    "107.233.550"   "43.654.609"
# [341] "34.315.147"    "67.933.033"    "169.198.132"   "25.320.079"
# [345] "126.123.248"   "32.760.917"    "151.182.001"   "53.323.977"
# [349] "48.880.134"    "142.918.741"   "148.096.466"   "109.508.324"
# [353] "49.912.790"    "43.339.936"    "133.109.196"   "245.267.622"
# [357] "1.779.730.252" "1.178.776.162" "321.275.673"   "218.240.636"
# [361] "1.367.910.021" "151.139.886"   "587.682.030"   "941.509.249"
# [365] "168.171.382"   "107.233.550"   "133.109.196"   "193.699.978"
# [369] "148.096.466"   "141.420.809"   "275.669.626"   "5.951.108"
# [373] "4.547.418"     "4.829.873"     "245.267.622"   "1.779.730.252"
# [377] "1.178.776.162" "321.275.673"   "218.240.636"   "1.367.910.021"
# [381] "151.139.886"   "587.682.030"   "941.509.249"   "168.171.382"
# [385] "107.233.550"   "133.109.196"   "193.699.978"   "60.819.145"
# [389] "251.775.054"   "54.965.296"    "815.642.450"   "245.010.202"
# [393] "383.038.883"   "61.821.545"    "657.308.948"   "57.098.497"
# [397] "66.262.839"    "54.079.110"    "39.546.954"    "43.654.609"
# [401] "271.708.452"   "43.339.936"    "126.123.248"   "31.857.392"
# [405] "42.188.665"    "22.927.653"    "16.536.933"    "17.531.943"
# [409] "23.767.799"    "60.819.145"    "251.775.054"   "54.965.296"
# [413] "815.642.450"   "245.010.202"   "383.038.883"   "61.821.545"
# [417] "657.308.948"   "57.098.497"    "66.262.839"    "54.079.110"
# [421] "39.546.954"    "43.654.609"    "271.708.452"   "43.339.936"
# [425] "126.123.248"   "8.880.736"     "6.857.903"     "6.938.597"
# [429] "6.867.055"     "6.480.720"     "11.878.503"    "6.446.611"
# [433] "5.968.934"     "5.940.738"     "11.778.196"    "8.177.318"
# [437] "6.656.463"     "6.492.948"     "7.694.389"     "5.843.535"
# [441] "6.197.605"     "220.866.384"   "180.160.266"   "386.437.949"
# [445] "142.918.741"   "140.397.028"   "227.152.677"   "45.573.588"
# [449] "84.836.384"    "786.707.238"   "190.349.987"   "51.675.352"
# [453] "102.177.470"   "121.851.870"   "99.552.792"    "71.272.101"
# [457] "43.516.280"    "25.511.421"    "75.444.294"    "24.014.122"
# [461] "51.765.213"    "220.866.384"   "180.160.266"   "386.437.949"
# [465] "142.918.741"   "140.397.028"   "227.152.677"   "45.573.588"
# [469] "84.836.384"    "786.707.238"   "190.349.987"   "51.675.352"
# [473] "102.177.470"   "121.851.870"   "99.552.792"    "25.320.079"
# [477] "22.566.446"    "27.080.983"    "16.666.446"    "13.738.576"
# [481] "14.901.473"    "118.010.096"   "114.830.649"   "868.938.537"
# [485] "48.880.134"    "109.508.324"   "628.076.118"   "67.933.033"
# [489] "31.186.337"    "45.929.391"    "69.526.656"    "53.323.977"
# [493] "39.494.267"    "26.816.334"    "118.010.096"   "114.830.649"
# [497] "868.938.537"   "48.880.134"    "109.508.324"   "628.076.118"
# [501] "67.933.033"    "31.186.337"    "45.929.391"    "69.526.656"
# [505] "53.323.977"    "39.494.267"    "26.816.334"    "2.147.295"
# [509] "1.178.447"     "1.733.340"     "127.256.142"   "188.216.746"
# [513] "210.533.930"   "40.680.546"    "42.081.074"    "29.460.945"
# [517] "32.760.917"    "34.268.716"    "118.497.374"   "44.299.678"
# [521] "328.676.348"   "49.912.790"    "34.315.147"    "25.204.096"
# [525] "32.775.607"

# %% [markdown]
# Identify values that became NA after conversion

# %%
ts_songs$cleaned_streams <- gsub("\\.", "", ts_songs$spotify_streams)
ts_songs$numeric_streams <- as.numeric(ts_songs$cleaned_streams)

# %% [markdown]
# Clean the "spotify_streams" column by removing extra characters and convert cleaned values to numeric values

# %%
evermore <- find_songs_by_album(ts_songs, "evermore (deluxe version)")

# %% [markdown]
# Use the "find_songs_by_album" function to extract all songs from "evermore (deluxe version)"

# %% [markdown]
# The "spotify_streams" column couldn't be immediately converted to numeric because some values in the spotify_streams column contained more than one '.' character. R treats any value with multiple '.' as invalid for numeric conversion, so they became NA.

# %%
nrow(evermore)
# Out:
# [1] 17

# %% [markdown]
# 17 songs were in "evermore (deluxe version)"

# %% [markdown]
# ## Filtering to a specific album and converting song duration to minutes

# %%
ts_songs <- ts_songs[ , !(names(ts_songs) %in% "track_lyrics")]
ts_1989 <- find_songs_by_album(ts_songs, "1989 (Taylor's Version) [Deluxe]")
nrow(ts_1989)
# Out:
# [1] 22

# %%
head(ts_1989)
# Out:
#    X...ID track_name                                    track_musical_genre
# 48 47     Welcome To New York (Taylor's Version)        Dance Pop
# 49 48     Blank Space (Taylor's Version)                Electropop
# 50 49     Style (Taylor's Version)                      Synth Pop
# 51 50     Out Of The Woods (Taylor's Version)           Synth Pop
# 52 51     All You Had To Do Was Stay (Taylor's Version) Synth Pop
# 53 52     Shake It Off (Taylor's Version)               Dance Pop
#    track_type duration_ms feature track_videoclip videoclip_views
# 48 B-Side     212600      No      No              0
# 49 B-Side     231833      No      No              0
# 50 B-Side     231000      No      No              0
# 51 B-Side     235800      No      No              0
# 52 B-Side     193289      No      No              0
# 53 B-Side     219209      No      No              0
#    spotify_streams spotify_global_peak album
# 48 102.221.045      6                  1989 (Taylor's Version) [Deluxe]
# 49 151.282.408      3                  1989 (Taylor's Version) [Deluxe]
# 50 182.418.311      1                  1989 (Taylor's Version) [Deluxe]
# 51 118.458.965      8                  1989 (Taylor's Version) [Deluxe]
# 52 88.205.974      10                  1989 (Taylor's Version) [Deluxe]
# 53 101.800.187     11                  1989 (Taylor's Version) [Deluxe]
#    track_number album_musical_genre album_type         release_date
# 48 1            Pop                 Compilation/Deluxe 27/10/2023
# 49 2            Pop                 Compilation/Deluxe 27/10/2023
# 50 3            Pop                 Compilation/Deluxe 27/10/2023
# 51 4            Pop                 Compilation/Deluxe 27/10/2023
# 52 5            Pop                 Compilation/Deluxe 27/10/2023
# 53 6            Pop                 Compilation/Deluxe 27/10/2023
#    album_physical_sales track_theme
# 48 0                    Happiness
# 49 0                    New love
# 50 0                    New love
# 51 0                    Complicated love/Losing love
# 52 0                    Broken heart/Anger
# 53 0                    Happiness
#    uri                                  acousticness danceability energy
# 48 spotify:track:4WUepByoeqcedHoYhSNHRt 0.00942      0.757        0.61
# 49 spotify:track:0108kcWLnn2HlH2kedi1gn 0.0885       0.733        0.733
# 50 spotify:track:3Vpk1hfMAQme8VJ0SNRSkd 0.000421     0.511        0.822
# 51 spotify:track:1OcSfkeCg9hRC2sFKB4IMJ 0.000537     0.545        0.885
# 52 spotify:track:2k0ZEeAqzvYMcx9Qt5aClQ 0.000656     0.588        0.721
# 53 spotify:track:50yNTF0Od55qnHLxYsA5Pw 0.0121       0.636        0.808
#    instrumentalness liveness loudness speechiness tempo   valence
# 48 3.66e-05         0.367    -4.84    0.0327      116.998 0.685
# 49 0.0              0.168    -5.376   0.067       96.057  0.701
# 50 0.0197           0.0899   -4.785   0.0397      94.868  0.305
# 51 5.59e-05         0.385    -5.968   0.0447      92.021  0.206
# 52 0.0              0.131    -5.579   0.0317      96.997  0.52
# 53 2.18e-05         0.359    -5.693   0.0729      160.058 0.917
#    numeric_streams cleaned_streams
# 48 102221045       102221045
# 49 151282408       151282408
# 50 182418311       182418311
# 51 118458965       118458965
# 52  88205974       88205974
# 53 101800187       101800187

# %%
ts_1989$duration_sec <- ts_1989$duration_ms / 1000
ts_1989$duration_min <- ts_1989$duration_sec / 60

convert_duration <- function(df) {
  df$duration_sec <- df$duration_ms / 1000
  df$duration_min <- df$duration_sec / 60
  return(df)
}
# Out:
#    X...ID track_name                                    track_musical_genre
# 48 47     Welcome To New York (Taylor's Version)        Dance Pop
# 49 48     Blank Space (Taylor's Version)                Electropop
# 50 49     Style (Taylor's Version)                      Synth Pop
# 51 50     Out Of The Woods (Taylor's Version)           Synth Pop
# 52 51     All You Had To Do Was Stay (Taylor's Version) Synth Pop
# 53 52     Shake It Off (Taylor's Version)               Dance Pop
#    track_type duration_ms feature track_videoclip videoclip_views
# 48 B-Side     212600      No      No              0
# 49 B-Side     231833      No      No              0
# 50 B-Side     231000      No      No              0
# 51 B-Side     235800      No      No              0
# 52 B-Side     193289      No      No              0
# 53 B-Side     219209      No      No              0
#    spotify_streams spotify_global_peak album
# 48 102.221.045      6                  1989 (Taylor's Version) [Deluxe]
# 49 151.282.408      3                  1989 (Taylor's Version) [Deluxe]
# 50 182.418.311      1                  1989 (Taylor's Version) [Deluxe]
# 51 118.458.965      8                  1989 (Taylor's Version) [Deluxe]
# 52 88.205.974      10                  1989 (Taylor's Version) [Deluxe]
# 53 101.800.187     11                  1989 (Taylor's Version) [Deluxe]
#    track_number album_musical_genre album_type         release_date
# 48 1            Pop                 Compilation/Deluxe 27/10/2023
# 49 2            Pop                 Compilation/Deluxe 27/10/2023
# 50 3            Pop                 Compilation/Deluxe 27/10/2023
# 51 4            Pop                 Compilation/Deluxe 27/10/2023
# 52 5            Pop                 Compilation/Deluxe 27/10/2023
# 53 6            Pop                 Compilation/Deluxe 27/10/2023
#    album_physical_sales track_theme
# 48 0                    Happiness
# 49 0                    New love
# 50 0                    New love
# 51 0                    Complicated love/Losing love
# 52 0                    Broken heart/Anger
# 53 0                    Happiness
#    uri                                  acousticness danceability energy
# 48 spotify:track:4WUepByoeqcedHoYhSNHRt 0.00942      0.757        0.61
# 49 spotify:track:0108kcWLnn2HlH2kedi1gn 0.0885       0.733        0.733
# 50 spotify:track:3Vpk1hfMAQme8VJ0SNRSkd 0.000421     0.511        0.822
# 51 spotify:track:1OcSfkeCg9hRC2sFKB4IMJ 0.000537     0.545        0.885
# 52 spotify:track:2k0ZEeAqzvYMcx9Qt5aClQ 0.000656     0.588        0.721
# 53 spotify:track:50yNTF0Od55qnHLxYsA5Pw 0.0121       0.636        0.808
#    instrumentalness liveness loudness speechiness tempo   valence
# 48 3.66e-05         0.367    -4.84    0.0327      116.998 0.685
# 49 0.0              0.168    -5.376   0.067       96.057  0.701
# 50 0.0197           0.0899   -4.785   0.0397      94.868  0.305
# 51 5.59e-05         0.385    -5.968   0.0447      92.021  0.206
# 52 0.0              0.131    -5.579   0.0317      96.997  0.52
# 53 2.18e-05         0.359    -5.693   0.0729      160.058 0.917
#    numeric_streams cleaned_streams duration_sec duration_min
# 48 102221045       102221045       212.600      3.543333
# 49 151282408       151282408       231.833      3.863883
# 50 182418311       182418311       231.000      3.850000
# 51 118458965       118458965       235.800      3.930000
# 52  88205974       88205974        193.289      3.221483
# 53 101800187       101800187       219.209      3.653483

# %% [markdown]
# Create new columns for duration in seconds and minutes and create function to covert duration

# %%
ts_1989_converted <- convert_duration(ts_1989)
head(ts_1989_converted)
# Out:
#    X...ID track_name                                    track_musical_genre
# 48 47     Welcome To New York (Taylor's Version)        Dance Pop
# 49 48     Blank Space (Taylor's Version)                Electropop
# 50 49     Style (Taylor's Version)                      Synth Pop
# 51 50     Out Of The Woods (Taylor's Version)           Synth Pop
# 52 51     All You Had To Do Was Stay (Taylor's Version) Synth Pop
# 53 52     Shake It Off (Taylor's Version)               Dance Pop
#    track_type duration_ms feature track_videoclip videoclip_views
# 48 B-Side     212600      No      No              0
# 49 B-Side     231833      No      No              0
# 50 B-Side     231000      No      No              0
# 51 B-Side     235800      No      No              0
# 52 B-Side     193289      No      No              0
# 53 B-Side     219209      No      No              0
#    spotify_streams spotify_global_peak album
# 48 102.221.045      6                  1989 (Taylor's Version) [Deluxe]
# 49 151.282.408      3                  1989 (Taylor's Version) [Deluxe]
# 50 182.418.311      1                  1989 (Taylor's Version) [Deluxe]
# 51 118.458.965      8                  1989 (Taylor's Version) [Deluxe]
# 52 88.205.974      10                  1989 (Taylor's Version) [Deluxe]
# 53 101.800.187     11                  1989 (Taylor's Version) [Deluxe]
#    track_number album_musical_genre album_type         release_date
# 48 1            Pop                 Compilation/Deluxe 27/10/2023
# 49 2            Pop                 Compilation/Deluxe 27/10/2023
# 50 3            Pop                 Compilation/Deluxe 27/10/2023
# 51 4            Pop                 Compilation/Deluxe 27/10/2023
# 52 5            Pop                 Compilation/Deluxe 27/10/2023
# 53 6            Pop                 Compilation/Deluxe 27/10/2023
#    album_physical_sales track_theme
# 48 0                    Happiness
# 49 0                    New love
# 50 0                    New love
# 51 0                    Complicated love/Losing love
# 52 0                    Broken heart/Anger
# 53 0                    Happiness
#    uri                                  acousticness danceability energy
# 48 spotify:track:4WUepByoeqcedHoYhSNHRt 0.00942      0.757        0.61
# 49 spotify:track:0108kcWLnn2HlH2kedi1gn 0.0885       0.733        0.733
# 50 spotify:track:3Vpk1hfMAQme8VJ0SNRSkd 0.000421     0.511        0.822
# 51 spotify:track:1OcSfkeCg9hRC2sFKB4IMJ 0.000537     0.545        0.885
# 52 spotify:track:2k0ZEeAqzvYMcx9Qt5aClQ 0.000656     0.588        0.721
# 53 spotify:track:50yNTF0Od55qnHLxYsA5Pw 0.0121       0.636        0.808
#    instrumentalness liveness loudness speechiness tempo   valence
# 48 3.66e-05         0.367    -4.84    0.0327      116.998 0.685
# 49 0.0              0.168    -5.376   0.067       96.057  0.701
# 50 0.0197           0.0899   -4.785   0.0397      94.868  0.305
# 51 5.59e-05         0.385    -5.968   0.0447      92.021  0.206
# 52 0.0              0.131    -5.579   0.0317      96.997  0.52
# 53 2.18e-05         0.359    -5.693   0.0729      160.058 0.917
#    numeric_streams cleaned_streams duration_sec duration_min
# 48 102221045       102221045       212.600      3.543333
# 49 151282408       151282408       231.833      3.863883
# 50 182418311       182418311       231.000      3.850000
# 51 118458965       118458965       235.800      3.930000
# 52  88205974       88205974        193.289      3.221483
# 53 101800187       101800187       219.209      3.653483

# %% [markdown]
# Now we have "duration_ms" converted into "duration_min" and "duration_sec" in the above data set

# %% [markdown]
# ## Finding the top YouTuber by subscribers within a genre

# %%
youtubers$subscribers2 <- as.numeric(gsub(",", "", youtubers$subscribers))

top_youtuber_by_genre <- function(df, genre) {
  genre_rows <- df[df$category == genre, ]
  max_row <- genre_rows[which.max(genre_rows$subscribers2), ]
  
  return(max_row)
}

# %% [markdown]
# Convert subscribers column to numeric and build a function to find the top-subscribed Youtuber in a genre

# %%
top_gaming <- top_youtuber_by_genre(youtubers, "Gaming")
top_gaming$Youtuber
top_gaming$subscribers2
# Out:
# [1] "PewDiePie"
# [1] 1.11e+08

# %% [markdown]
# Test the function and cross check results which are "PewDiePie", with 111,000,000 subscribers

# %%
table(youtubers$category)
# Out:
#                            Autos & Vehicles                Comedy
#                    27                     1                    63
#             Education         Entertainment      Film & Animation
#                    46                   241                    52
#                Gaming         Howto & Style                Movies
#                   102                    45                     2
#                 Music       News & Politics Nonprofits & Activism
#                   222                    27                     2
#        People & Blogs        Pets & Animals  Science & Technology
#                   119                     6                    18
#                 Shows                Sports              Trailers
#                    14                    10                     2
#       Travel & Events
#                     1

# %%
top_music <- top_youtuber_by_genre(youtubers, "Music")
top_music$Youtuber
top_music$subscribers2
# Out:
# [1] "T-Series"
# [1] 2.22e+08

# %% [markdown]
# I used the second catagory "Music" with output as "T-Series", with

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
